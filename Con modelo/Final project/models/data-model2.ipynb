# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv("../data/datos_limpios.csv")
#veamos cuantas dimensiones y registros contiene
data.shape
data.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1          id  bedrooms  bathrooms  sqft_living  \
# 0           0          1995  7129300520         3       1.00         1180
# 1           1             1  6414100192         3       2.25         2570
# 2           2             2  5631500400         2       1.00          770
# 3           3             3  2487200875         4       3.00         1960
# 4           4             4  1954400510         3       2.00         1680
#
#    sqft_lot  floors  condition  grade  sqft_above  sqft_basement  yr_built  \
# 0      5650     1.0          3      7        1180           1995      1955
# 1      7242     2.0          3      7        2170            400      1951
# 2     10000     1.0          3      6         770           1995      1933
# 3      5000     1.0          5      7        1050            910      1965
# 4      8080     1.0          3      8        1680           1995      1987
#
#    yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15   price
# 0          1995    98178  47.5112 -122.257           1340        5650  221900
# 1          1991    98125  47.7210 -122.319           1690        7639  538000
# 2          1995    98028  47.7379 -122.233           2720        8062  180000
# 3          1995    98136  47.5208 -122.393           1360        5000  604000
# 4          1995    98074  47.6168 -122.045           1800        7503  510000

# %%
fig = plt.figure(figsize=(14,14))
plt.scatter(data['price'],data['sqft_living'])
plt.plot(data['price'],data['sqft_living'],data['bedrooms'])
plt.xlabel('Price')
plt.ylabel('m2')
plt.grid()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3380/1751756894.py in <module>
#       4 plt.xlabel('Price')
#       5 plt.ylabel('m2')
# ----> 6 plt.zlabel('uds')
#       7 plt.grid()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'zlabel'
